# %%
import pandas as pd

# %%
df=pd.read_csv('data.csv')
df
# Out:
#       Unnamed: 0  acousticness  danceability  duration_ms  energy  \
# 0              0       0.01020         0.833       204600   0.434
# 1              1       0.19900         0.743       326933   0.359
# 2              2       0.03440         0.838       185707   0.412
# 3              3       0.60400         0.494       199413   0.338
# 4              4       0.18000         0.678       392893   0.561
# ...          ...           ...           ...          ...     ...
# 2012        2012       0.00106         0.584       274404   0.932
# 2013        2013       0.08770         0.894       182182   0.892
# 2014        2014       0.00857         0.637       207200   0.935
# 2015        2015       0.00164         0.557       185600   0.992
# 2016        2016       0.00281         0.446       204520   0.915
#
#       instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0             0.021900    2    0.1650    -8.795     1       0.4310  150.062
# ...

# %% [markdown]
# ACTIVITIES TO SHARPEN SKILLS

# %% [markdown]
# Q1)

# %%
df2=df[df['energy']>0.4]
df2
# Out:
#       Unnamed: 0  acousticness  danceability  duration_ms  energy  \
# 0              0       0.01020         0.833       204600   0.434
# 2              2       0.03440         0.838       185707   0.412
# 4              4       0.18000         0.678       392893   0.561
# 5              5       0.00479         0.804       251333   0.560
# 6              6       0.01450         0.739       241400   0.472
# ...          ...           ...           ...          ...     ...
# 2012        2012       0.00106         0.584       274404   0.932
# 2013        2013       0.08770         0.894       182182   0.892
# 2014        2014       0.00857         0.637       207200   0.935
# 2015        2015       0.00164         0.557       185600   0.992
# 2016        2016       0.00281         0.446       204520   0.915
#
#       instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0             0.021900    2    0.1650    -8.795     1       0.4310  150.062
# ...

# %%
df2[['song_title','artist']]
# Out:
#                                 song_title          artist
# 0                                 Mask Off          Future
# 2                             Xanny Family          Future
# 4                           Parallel Lines     Junior Boys
# 5                                 Sneakin’           Drake
# 6                              Childs Play           Drake
# ...                                    ...             ...
# 2012   Like A Bitch - Kill The Noise Remix  Kill The Noise
# 2013                                 Candy  Dillon Francis
# 2014  Habit - Dack Janiels & Wenzday Remix        Rain Man
# 2015                         First Contact      Twin Moons
# 2016                    I Wanna Get Better       Bleachers
#
# [1830 rows x 2 columns]

# %% [markdown]
# Q2)

# %%
df2=df[df['duration_ms']<300000]
df2
# Out:
#       Unnamed: 0  acousticness  danceability  duration_ms  energy  \
# 0              0       0.01020         0.833       204600   0.434
# 2              2       0.03440         0.838       185707   0.412
# 3              3       0.60400         0.494       199413   0.338
# 5              5       0.00479         0.804       251333   0.560
# 6              6       0.01450         0.739       241400   0.472
# ...          ...           ...           ...          ...     ...
# 2012        2012       0.00106         0.584       274404   0.932
# 2013        2013       0.08770         0.894       182182   0.892
# 2014        2014       0.00857         0.637       207200   0.935
# 2015        2015       0.00164         0.557       185600   0.992
# 2016        2016       0.00281         0.446       204520   0.915
#
#       instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0             0.021900    2    0.1650    -8.795     1       0.4310  150.062
# ...

# %%
df2.sort_values(by='tempo',ascending=False,inplace=True)
df2
# Out:
# C:\Users\Aryan\AppData\Local\Temp\ipykernel_21444\466493123.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.sort_values(by='tempo',ascending=False,inplace=True)
#       Unnamed: 0  acousticness  danceability  duration_ms  energy  \
# 124          124         0.674         0.462       226333  0.4490
# 718          718         0.717         0.345       237973  0.3130
# 1960        1960         0.537         0.191       184800  0.6640
# 1711        1711         0.101         0.403       201720  0.8830
# 809          809         0.615         0.508       174067  0.2470
# ...          ...           ...           ...          ...     ...
# 1542        1542         0.924         0.533       221733  0.1480
# 1544        1544         0.846         0.569       282320  0.1170
# ...

# %%
df2=df2[['song_title','artist']][:10]
df2.reset_index(inplace=True,drop=True)
df2
# Out:
#              song_title            artist
# 0      Danger and Dread        Brown Bird
# 1           Hannah Hunt   Vampire Weekend
# 2            Puppy Love      Donny Osmond
# 3               Amazing     Big Time Rush
# 4       Tupelo - Part 1       Pop Staples
# 5    Living Every Dream            Antwon
# 6  The Shaping Sickness  Shadow of Intent
# 7        Willing & Able        Disclosure
# 8             Mad Love.              JoJo
# 9       Wake Bake Skate            FIDLAR

# %% [markdown]
# Q3)

# %%
df2=df[(df['artist']=='Drake')&(df['energy']>0.5)]
df2
# Out:
#       Unnamed: 0  acousticness  danceability  duration_ms  energy  \
# 5              5       0.00479         0.804       251333   0.560
# 37            37       0.05650         0.853       205879   0.547
# 117          117       0.00257         0.896       267024   0.623
# 154          154       0.00157         0.790       217707   0.676
# 440          440       0.36900         0.662       236733   0.571
# 589          589       0.04250         0.790       173160   0.531
# 779          779       0.76300         0.707       275227   0.709
# 1016        1016       0.01030         0.745       143214   0.822
# 1218        1218       0.21900         0.427       257760   0.861
# 1223        1223       0.04310         0.697       277387   0.527
#
#       instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 5             0.000000    8    0.1640    -6.682     1       0.1850   85.023
# 37            0.000000    1    0.3410    -7.535     1       0.1940  142.065
# ...

# %%
print(df2['song_title'])
# Out:
# 5                      Sneakin’
# 37                      Jumpman
# 117               Hotline Bling
# 154                   Big Rings
# 440                   Headlines
# 589     Started From the Bottom
# 779     0 To 100 / The Catch Up
# 1016           Skepta Interlude
# 1218            Best I Ever Had
# 1223                  Take Care
# Name: song_title, dtype: object

# %%
df
# Out:
#       Unnamed: 0  acousticness  danceability  duration_ms  energy  \
# 0              0       0.01020         0.833       204600   0.434
# 1              1       0.19900         0.743       326933   0.359
# 2              2       0.03440         0.838       185707   0.412
# 3              3       0.60400         0.494       199413   0.338
# 4              4       0.18000         0.678       392893   0.561
# ...          ...           ...           ...          ...     ...
# 2012        2012       0.00106         0.584       274404   0.932
# 2013        2013       0.08770         0.894       182182   0.892
# 2014        2014       0.00857         0.637       207200   0.935
# 2015        2015       0.00164         0.557       185600   0.992
# 2016        2016       0.00281         0.446       204520   0.915
#
#       instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0             0.021900    2    0.1650    -8.795     1       0.4310  150.062
# ...

# %% [markdown]
# QUESTIONS GIVEN AFTER COMPLETING THE ACTIVITY

# %% [markdown]
# Q1)

# %%
df2=df.sort_values(by='instrumentalness',ascending=False)
df2
# Out:
#       Unnamed: 0  acousticness  danceability  duration_ms  energy  \
# 1313        1313      0.000085         0.170       319582  0.8660
# 271          271      0.123000         0.473       153973  0.8650
# 1575        1575      0.967000         0.384       206040  0.0544
# 1619        1619      0.003380         0.569       190155  0.8960
# 725          725      0.054300         0.810       527705  0.9490
# ...          ...           ...           ...          ...     ...
# 1421        1421      0.006120         0.729       275720  0.8380
# 1422        1422      0.005890         0.662       267720  0.8080
# 1423        1423      0.001840         0.541       225427  0.6090
# 1424        1424      0.008400         0.629       242373  0.7000
# 1008        1008      0.671000         0.539       166304  0.7400
#
#       instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 1313             0.976    4    0.5690    -7.304     1       0.1010  117.539
# ...

# %%
df2=df2[['instrumentalness','song_title','artist']][:10]
df2.reset_index(inplace=True,drop=True)
df2
# Out:
#    instrumentalness                            song_title  \
# 0             0.976                       Senseless Order
# 1             0.968  So Destroyed (channeling Rage Peace)
# 2             0.964             A Hundred Dreams from Now
# 3             0.958                                 Raven
# 4             0.957                     Strandbar (disko)
# 5             0.956                        Almas vaggvisa
# 6             0.955                            Pitchblack
# 7             0.954                       Prismatic Abyss
# 8             0.954                               Yebisah
# 9             0.952                        Chasing Heaven
#
#                      artist
# 0        Signs of the Swarm
# 1               Prince Rama
# 2                Ray Bryant
# 3             John Dahlbäck
# 4                Todd Terje
# 5         Jan Lundgren Trio
# 6  Walking Dead On Broadway
# 7           Aversions Crown
# 8               Mark Knight
# 9                Bassnectar

# %% [markdown]
# Q2)

# %%
df2=df.groupby('artist')[['tempo']].mean()
df2.reset_index(inplace=True)
df2
# Out:
#                  artist       tempo
# 0                   !!!  120.004000
# 1                *NSYNC  140.488375
# 2                  10cm  116.955500
# 3              2 Chainz  111.187333
# 4           2 LIVE CREW  131.644000
# ...                 ...         ...
# 1338            tobyMac  102.984000
# 1339      권나무 Kwon Tree   83.625000
# 1340  도시총각 Dosichonggak  101.780000
# 1341  카우칩스 The CowChips  100.042000
# 1342      플랫핏 Flat Feet  142.952000
#
# [1343 rows x 2 columns]

# %%
df2.sort_values(by='tempo',ascending=False,inplace=True)
df2[:10]
# Out:
#                      artist    tempo
# 171              Brown Bird  209.686
# 354            Donny Osmond  203.822
# 920             Pop Staples  200.749
# 58                   Antwon  200.035
# 1029       Shadow of Intent  199.988
# 226              Chris Bear  192.272
# 132               Bleachers  190.013
# 164   Brillz & Teddy Tuxedo  189.935
# 1061          Soul For Real  188.256
# 1051          Skye Sweetnam  188.058
