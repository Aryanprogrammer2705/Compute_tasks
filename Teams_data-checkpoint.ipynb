# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
teams=pd.read_csv('teams.csv')
team_attributes=pd.read_csv('team_attributes.csv')
leagues=pd.read_csv('leagues.csv')
matches=pd.read_csv('matches.csv')
countries=pd.read_csv('countries.csv')

# %%
countries
# Out:
#     Unnamed: 0     id         name
# 0            0      1      Belgium
# 1            1   1729      England
# 2            2   4769       France
# 3            3   7809      Germany
# 4            4  10257        Italy
# 5            5  13274  Netherlands
# 6            6  15722       Poland
# 7            7  17642     Portugal
# 8            8  19694     Scotland
# 9            9  21518        Spain
# 10          10  24558  Switzerland

# %%
leagues
# Out:
#     Unnamed: 0     id  country_id                      name   id.1  \
# 0            0      1           1    Belgium Jupiler League      1
# 1            1   1729        1729    England Premier League   1729
# 2            2   4769        4769            France Ligue 1   4769
# 3            3   7809        7809     Germany 1. Bundesliga   7809
# 4            4  10257       10257             Italy Serie A  10257
# 5            5  13274       13274    Netherlands Eredivisie  13274
# 6            6  15722       15722        Poland Ekstraklasa  15722
# 7            7  17642       17642  Portugal Liga ZON Sagres  17642
# 8            8  19694       19694   Scotland Premier League  19694
# 9            9  21518       21518           Spain LIGA BBVA  21518
# 10          10  24558       24558  Switzerland Super League  24558
#
#          name.1
# 0       Belgium
# 1       England
# 2        France
# 3       Germany
# 4         Italy
# 5   Netherlands
# 6        Poland
# 7      Portugal
# ...

# %%
matches
# Out:
#        Unnamed: 0     id  country_id  league_id     season  stage  \
# 0               0      1           1          1  2008/2009      1
# 1               1      2           1          1  2008/2009      1
# 2               2      3           1          1  2008/2009      1
# 3               3      4           1          1  2008/2009      1
# 4               4      5           1          1  2008/2009      1
# ...           ...    ...         ...        ...        ...    ...
# 25974       25974  25975       24558      24558  2015/2016      9
# 25975       25975  25976       24558      24558  2015/2016      9
# 25976       25976  25977       24558      24558  2015/2016      9
# 25977       25977  25978       24558      24558  2015/2016      9
# 25978       25978  25979       24558      24558  2015/2016      9
#
#                       date  match_api_id  home_team_api_id  away_team_api_id  \
# 0      2008-08-17 00:00:00        492473              9987              9993
# ...

# %%
teams
# Out:
#      Unnamed: 0     id  team_api_id  team_fifa_api_id      team_long_name  \
# 0             0      1         9987             673.0            KRC Genk
# 1             1      2         9993             675.0        Beerschot AC
# 2             2      3        10000           15005.0    SV Zulte-Waregem
# 3             3      4         9994            2007.0    Sporting Lokeren
# 4             4      5         9984            1750.0   KSV Cercle Brugge
# ..          ...    ...          ...               ...                 ...
# 294         294  49479        10190             898.0       FC St. Gallen
# 295         295  49837        10191            1715.0             FC Thun
# 296         296  50201         9777             324.0         Servette FC
# 297         297  50204         7730            1862.0  FC Lausanne-Sports
# 298         298  51606         7896               NaN              Lugano
#
#     team_short_name
# 0               GEN
# 1               BAC
# ...

# %%
team_attributes
# Out:
#       Unnamed: 0    id  team_fifa_api_id  team_api_id                 date  \
# 0              0     1               434         9930  2010-02-22 00:00:00
# 1              1     2               434         9930  2014-09-19 00:00:00
# 2              2     3               434         9930  2015-09-10 00:00:00
# 3              3     4                77         8485  2010-02-22 00:00:00
# 4              4     5                77         8485  2011-02-22 00:00:00
# ...          ...   ...               ...          ...                  ...
# 1453        1453  1454             15005        10000  2011-02-22 00:00:00
# 1454        1454  1455             15005        10000  2012-02-22 00:00:00
# 1455        1455  1456             15005        10000  2013-09-20 00:00:00
# 1456        1456  1457             15005        10000  2014-09-19 00:00:00
# 1457        1457  1458             15005        10000  2015-09-10 00:00:00
#
# ...

# %%
leagues.rename(columns={'name.1':'Country','name':'League'},inplace=True)
leagues=leagues[(leagues['Country']=='England')|(leagues['Country']=='Germany')|(leagues['Country']=='France')|(leagues['Country']=='Italy')|(leagues['Country']=='Spain')]
leagues
# Out:
#    Unnamed: 0     id  country_id                  League   id.1  Country
# 1           1   1729        1729  England Premier League   1729  England
# 2           2   4769        4769          France Ligue 1   4769   France
# 3           3   7809        7809   Germany 1. Bundesliga   7809  Germany
# 4           4  10257       10257           Italy Serie A  10257    Italy
# 9           9  21518       21518         Spain LIGA BBVA  21518    Spain

# %%
team_attributes['date']=team_attributes['date'].apply(lambda x: x.split()[0])
team_attributes['date']=team_attributes['date'].apply(lambda x: x.split('-')[0])
team_attributes
# Out:
#       Unnamed: 0    id  team_fifa_api_id  team_api_id  date  buildUpPlaySpeed  \
# 0              0     1               434         9930  2010                60
# 1              1     2               434         9930  2014                52
# 2              2     3               434         9930  2015                47
# 3              3     4                77         8485  2010                70
# 4              4     5                77         8485  2011                47
# ...          ...   ...               ...          ...   ...               ...
# 1453        1453  1454             15005        10000  2011                52
# 1454        1454  1455             15005        10000  2012                54
# 1455        1455  1456             15005        10000  2013                54
# 1456        1456  1457             15005        10000  2014                54
# 1457        1457  1458             15005        10000  2015                54
#
# ...

# %%
teams=team_attributes.merge(teams[['team_fifa_api_id','team_long_name']])
teams.rename(columns={'date':'season'},inplace=True)
teams
# Out:
#       Unnamed: 0    id  team_fifa_api_id  team_api_id season  \
# 0              0     1               434         9930   2010
# 1              1     2               434         9930   2014
# 2              2     3               434         9930   2015
# 3              3     4                77         8485   2010
# 4              4     5                77         8485   2011
# ...          ...   ...               ...          ...    ...
# 1468        1453  1454             15005        10000   2011
# 1469        1454  1455             15005        10000   2012
# 1470        1455  1456             15005        10000   2013
# 1471        1456  1457             15005        10000   2014
# 1472        1457  1458             15005        10000   2015
#
#       buildUpPlaySpeed buildUpPlaySpeedClass  buildUpPlayDribbling  \
# 0                   60              Balanced                   NaN
# 1                   52              Balanced                  48.0
# ...
