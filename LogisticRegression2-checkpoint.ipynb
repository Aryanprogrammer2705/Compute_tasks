# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import plot_confusion_matrix

# %%
df=pd.read_csv('Ad Click Data.csv')
df
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                       68.95   35     61833.90                256.09
# 1                       80.23   31     68441.85                193.77
# 2                       69.47   26     59785.94                236.50
# 3                       74.15   29     54806.18                245.89
# 4                       68.37   35     73889.99                225.58
# ..                        ...  ...          ...                   ...
# 995                     72.97   30     71384.57                208.58
# 996                     51.30   45     67782.17                134.42
# 997                       NaN   51     42415.72                120.37
# 998                     55.55   19     41920.79                187.95
# 999                     45.01   26     29875.80                178.35
#
#                              Ad Topic Line            City  Male  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Daily Time Spent on Site  987 non-null    float64
#  1   Age                       1000 non-null   int64
#  2   Area Income               987 non-null    float64
#  3   Daily Internet Usage      989 non-null    float64
#  4   Ad Topic Line             1000 non-null   object
#  5   City                      999 non-null    object
#  6   Male                      997 non-null    float64
#  7   Country                   991 non-null    object
#  8   Timestamp                 1000 non-null   object
#  9   Clicked on Ad             1000 non-null   int64
# dtypes: float64(4), int64(2), object(4)
# memory usage: 78.2+ KB

# %%
df.isna().sum()
# Out:
# Daily Time Spent on Site    13
# Age                          0
# Area Income                 13
# Daily Internet Usage        11
# Ad Topic Line                0
# City                         1
# Male                         3
# Country                      9
# Timestamp                    0
# Clicked on Ad                0
# dtype: int64

# %%
sns.barplot(x='Male',y='Daily Time Spent on Site',data=df)
plt.show()

# %% [markdown]
# Whether it is male or female,both genders are spending on an average equal time on the site.

# %%
df=df.drop(['Ad Topic Line','City','Country','Timestamp'],axis=1)
df
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  Male  \
# 0                       68.95   35     61833.90                256.09   0.0
# 1                       80.23   31     68441.85                193.77   1.0
# 2                       69.47   26     59785.94                236.50   0.0
# 3                       74.15   29     54806.18                245.89   1.0
# 4                       68.37   35     73889.99                225.58   0.0
# ..                        ...  ...          ...                   ...   ...
# 995                     72.97   30     71384.57                208.58   1.0
# 996                     51.30   45     67782.17                134.42   1.0
# 997                       NaN   51     42415.72                120.37   1.0
# 998                     55.55   19     41920.79                187.95   0.0
# 999                     45.01   26     29875.80                178.35   0.0
#
#      Clicked on Ad
# 0                0
# ...

# %%
df.isna().sum()
# Out:
# Daily Time Spent on Site    13
# Age                          0
# Area Income                 13
# Daily Internet Usage        11
# Male                         3
# Clicked on Ad                0
# dtype: int64

# %%
df.corr()
# Out:
#                           Daily Time Spent on Site       Age  Area Income  \
# Daily Time Spent on Site                  1.000000 -0.331424     0.308266
# Age                                      -0.331424  1.000000    -0.179343
# Area Income                               0.308266 -0.179343     1.000000
# Daily Internet Usage                      0.518294 -0.370481     0.338080
# Male                                     -0.020260 -0.020530     0.004326
# Clicked on Ad                            -0.746514  0.492531    -0.477576
#
#                           Daily Internet Usage      Male  Clicked on Ad
# Daily Time Spent on Site              0.518294 -0.020260      -0.746514
# Age                                  -0.370481 -0.020530       0.492531
# Area Income                           0.338080  0.004326      -0.477576
# Daily Internet Usage                  1.000000  0.028034      -0.789693
# Male                                  0.028034  1.000000      -0.035093
# ...

# %%
df['Daily Time Spent on Site']=df.groupby(['Age','Clicked on Ad'])['Daily Time Spent on Site'].apply(lambda x: x.fillna(x.mean()))
df
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  Male  \
# 0                   68.950000   35     61833.90                256.09   0.0
# 1                   80.230000   31     68441.85                193.77   1.0
# 2                   69.470000   26     59785.94                236.50   0.0
# 3                   74.150000   29     54806.18                245.89   1.0
# 4                   68.370000   35     73889.99                225.58   0.0
# ..                        ...  ...          ...                   ...   ...
# 995                 72.970000   30     71384.57                208.58   1.0
# 996                 51.300000   45     67782.17                134.42   1.0
# 997                 52.184444   51     42415.72                120.37   1.0
# 998                 55.550000   19     41920.79                187.95   0.0
# 999                 45.010000   26     29875.80                178.35   0.0
#
#      Clicked on Ad
# 0                0
# ...

# %%
df.isna().sum()
# Out:
# Daily Time Spent on Site     0
# Age                          0
# Area Income                 13
# Daily Internet Usage        11
# Male                         3
# Clicked on Ad                0
# dtype: int64

# %%
df['Area Income']=df.groupby(['Age','Clicked on Ad'])['Area Income'].apply(lambda x: x.fillna(x.mean()))
df
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  Male  \
# 0                   68.950000   35     61833.90                256.09   0.0
# 1                   80.230000   31     68441.85                193.77   1.0
# 2                   69.470000   26     59785.94                236.50   0.0
# 3                   74.150000   29     54806.18                245.89   1.0
# 4                   68.370000   35     73889.99                225.58   0.0
# ..                        ...  ...          ...                   ...   ...
# 995                 72.970000   30     71384.57                208.58   1.0
# 996                 51.300000   45     67782.17                134.42   1.0
# 997                 52.184444   51     42415.72                120.37   1.0
# 998                 55.550000   19     41920.79                187.95   0.0
# 999                 45.010000   26     29875.80                178.35   0.0
#
#      Clicked on Ad
# 0                0
# ...

# %%
df.isna().sum()
# Out:
# Daily Time Spent on Site     0
# Age                          0
# Area Income                  0
# Daily Internet Usage        11
# Male                         3
# Clicked on Ad                0
# dtype: int64

# %%
df['Daily Internet Usage']=df.groupby(['Age','Clicked on Ad'])['Daily Internet Usage'].apply(lambda x: x.fillna(x.mean()))
df
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  Male  \
# 0                   68.950000   35     61833.90                256.09   0.0
# 1                   80.230000   31     68441.85                193.77   1.0
# 2                   69.470000   26     59785.94                236.50   0.0
# 3                   74.150000   29     54806.18                245.89   1.0
# 4                   68.370000   35     73889.99                225.58   0.0
# ..                        ...  ...          ...                   ...   ...
# 995                 72.970000   30     71384.57                208.58   1.0
# 996                 51.300000   45     67782.17                134.42   1.0
# 997                 52.184444   51     42415.72                120.37   1.0
# 998                 55.550000   19     41920.79                187.95   0.0
# 999                 45.010000   26     29875.80                178.35   0.0
#
#      Clicked on Ad
# 0                0
# ...

# %%
df.isna().sum()
# Out:
# Daily Time Spent on Site    0
# Age                         0
# Area Income                 0
# Daily Internet Usage        0
# Male                        3
# Clicked on Ad               0
# dtype: int64

# %%
df=df.drop('Male',axis=1)
df
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                   68.950000   35     61833.90                256.09
# 1                   80.230000   31     68441.85                193.77
# 2                   69.470000   26     59785.94                236.50
# 3                   74.150000   29     54806.18                245.89
# 4                   68.370000   35     73889.99                225.58
# ..                        ...  ...          ...                   ...
# 995                 72.970000   30     71384.57                208.58
# 996                 51.300000   45     67782.17                134.42
# 997                 52.184444   51     42415.72                120.37
# 998                 55.550000   19     41920.79                187.95
# 999                 45.010000   26     29875.80                178.35
#
#      Clicked on Ad
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ...

# %%
sns.countplot(x='Clicked on Ad',data=df)
plt.show()

# %% [markdown]
# Target variable data is balanced.

# %%
sns.set()
sns.distplot(df['Daily Time Spent on Site'])
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Most people spend around 75 to 80 mins on the site.

# %%
sns.set()
sns.distplot(df['Age'])
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Most people visiting the site are in the age range of 30 to 35 years.

# %%
sns.scatterplot(x=df['Age'],y=df['Daily Time Spent on Site'],hue=df['Clicked on Ad'])
plt.show()

# %% [markdown]
# The more the time people are spending on the site, the lesser is the possibility to click on the ads with exception seen in the people aged more than 50.

# %%
sns.scatterplot(x=df['Age'],y=df['Area Income'],hue=df['Clicked on Ad'])
plt.show()

# %% [markdown]
# The more is the Area Income lesser is the possibility to click on the ads with exception seen in the people aged more than 50.

# %%
sns.scatterplot(x=df['Age'],y=df['Daily Internet Usage'],hue=df['Clicked on Ad'])
plt.show()

# %% [markdown]
# The more is the Daily Internet Usage lesser is the possibility to click on the ads with exception seen in the people aged more than 50.

# %%
X=df.iloc[:,:4]
Y=df['Clicked on Ad']

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3,random_state=0)

# %%
lr=LogisticRegression()

# %%
lr.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
Y_test_pred=lr.predict(X_test)
accuracy=accuracy_score(Y_test_pred,Y_test)
accuracy
# Out:
# 0.9133333333333333

# %%
Y_train_pred=lr.predict(X_train)
accuracy=accuracy_score(Y_train_pred,Y_train)
accuracy
# Out:
# 0.89

# %%
plot_confusion_matrix(lr,X_test,Y_test)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
